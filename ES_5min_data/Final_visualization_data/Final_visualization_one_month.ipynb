# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importent libraries
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pd.set_option('display.max_columns',400)
pd.set_option('display.max_rows',400)

# %%
Final_df = pd.read_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Final_visualization_data/one_month_visualize_Final_data_with_Defence_P_L.csv")

# %%
#Final_df.drop(columns=["Unnamed: 0"],axis=1,inplace=True)
Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])

# # Define the start and end times for filtering
# start_time = '2021-10-01 00:00:00'
# end_time = '2021-10-01 03:00:00'

# # Filter the DataFrame for the specific time range
# Final_df = Final_df[(Final_df['Time Stamp'] > start_time) & (Final_df['Time Stamp'] <= end_time)]

# %%
Final_df.shape
# Out:
# (8410, 43)

# %% [markdown]
# ## logic to visualize 1 month of data

# %%
import pandas as pd
import plotly.graph_objects as go

# Ensure that the 'Time Stamp' column is in datetime format
Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])

# Function to create a candlestick chart with specified annotations
def create_candlestick_chart(df, chart_title, annotations):
    fig = go.Figure(data=[go.Candlestick(
        x=df['Time Stamp'],
        open=df['Open'],
        high=df['High'],
        low=df['Low'],
        close=df['Close'],
        name='Candlestick'
    )])

    # Function to add annotations
    def add_annotations(column, y_col, symbol, color, name):
        signals = df[df[column] != 0]
        if signals.empty:
            # Add default annotation if no signals are present
            fig.add_trace(go.Scatter(x=[df['Time Stamp'].iloc[0]],
                                     y=[df['Low'].min()],
                                     mode='markers',
                                     marker=dict(symbol=symbol, size=10, color=color),
                                     name=name))
        else:
            fig.add_trace(go.Scatter(x=signals['Time Stamp'],
                                     y=signals[y_col],
                                     mode='markers+text',
                                     marker=dict(symbol=symbol, size=10, color=color),
                                     text=signals[column].round(2),  # Display rounded values for hovering
                                     textposition='top center',
                                     name=name))

    # Add specified annotations
    for annotation in annotations:
        add_annotations(*annotation)

    # Update layout
    fig.update_layout(title=chart_title,
                      xaxis_title='Time',
                      yaxis_title='Price',
                      xaxis_rangeslider_visible=True,
                      height=800,
                      width=1500)

    return fig

# First Candlestick Chart
annotations_1 = [
    ('Entry_T', 'Low', 'triangle-up', 'green', 'Entry_T'),
    ('Defence_T', 'High', 'triangle-down', 'red', 'Defence_T'),
    ('Stop_T', 'Low', 'x', 'black', 'Stop_T'),
    ('Target_T', 'High', 'star', 'blue', 'Target_T'),
    ('T_D_Profit', 'High', 'circle', 'green', 'T_D_Profit'),
    ('T_D_Loss', 'Low', 'circle', 'red', 'T_D_Loss'),
]

fig1 = create_candlestick_chart(Final_df, 'Candlestick Chart with TRADER_DATA Annotations', annotations_1)

# Second Candlestick Chart
annotations_2 = [
    ('Entry_C', 'Low', 'triangle-up', 'green', 'Entry_C'),
    ('Defence_C', 'High', 'triangle-down', 'red', 'Defence_C'),
    ('Stop_C', 'Low', 'x', 'black', 'Stop_C'),
    ('Target_C', 'High', 'star', 'blue', 'Target_C'),
    ('C_D_Profit', 'High', 'circle', 'lightgreen', 'C_D_Profit'),
    ('C_D_Loss', 'Low', 'circle', 'lightcoral', 'C_D_Loss'),
]

fig2 = create_candlestick_chart(Final_df, 'Candlestick Chart with CALCULATED_DATA Annotations', annotations_2)

# Third Candlestick Chart
annotations_3 = [
    ('Entry_C', 'Low', 'triangle-up', 'green', 'Entry_C'),
    ('Defence_C', 'High', 'triangle-down', 'red', 'Defence_C'),
    ('Stop_C', 'Low', 'x', 'black', 'Stop_C'),
    ('Target_C', 'High', 'star', 'blue', 'Target_C'),
    ('I_D_Profit', 'High', 'circle', 'blue', 'I_D_Profit'),
    ('I_D_Loss', 'Low', 'circle', 'orange', 'I_D_Loss'),
]

fig3 = create_candlestick_chart(Final_df, 'Candlestick Chart with IDEAL_DATA Annotations', annotations_3)

# Show the plots
fig1.show()
fig2.show()
fig3.show()

# Save the figures as HTML files
fig1.write_html('/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Final_visualization_data/Plotely_Plots/candlestick_chart_TRADER_DATA_annotations_numbers.html')
fig2.write_html('/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Final_visualization_data/Plotely_Plots/candlestick_chart_CALCULATED_DATA_annotations_numbers.html')
fig3.write_html('/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Final_visualization_data/Plotely_Plots/candlestick_chart_IDEAL_DATA_annotations_numbers.html')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd
import plotly.graph_objects as go

# Ensure that the 'Time Stamp' column is in datetime format
Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])

# Function to create a candlestick chart with specified annotations
def create_candlestick_chart(df, chart_title, annotations):
    fig = go.Figure(data=[go.Candlestick(
        x=df['Time Stamp'],
        open=df['Open'],
        high=df['High'],
        low=df['Low'],
        close=df['Close'],
        name='Candlestick'
    )])

    # Function to add annotations
    def add_annotations(column, y_col, symbol, color, name, hover_text):
        signals = df[df[column] != 0]
        if not signals.empty:
            fig.add_trace(go.Scatter(
                x=signals['Time Stamp'],
                y=signals[y_col],
                mode='markers',
                marker=dict(symbol=symbol, size=10, color=color),
                hovertext=[hover_text.format(val) for val in signals[y_col]],
                hoverinfo='text',
                name=name
            ))

    # Define specific hover text for each annotation
    hover_texts = {
        'Entry_T': 'Entry_T Value: {:.2f}',
        'Defence_T': 'Defence_T Value: {:.2f}',
        'Stop_T': 'Stop_T Value: {:.2f}',
        'Target_T': 'Target_T Value: {:.2f}',
        'T_D_Profit': 'T_D_Profit Value: {:.2f}',
        'T_D_Loss': 'T_D_Loss Value: {:.2f}',
        'Entry_C': 'Entry_C Value: {:.2f}',
        'Defence_C': 'Defence_C Value: {:.2f}',
        'Stop_C': 'Stop_C Value: {:.2f}',
        'Target_C': 'Target_C Value: {:.2f}',
        'C_D_Profit': 'C_D_Profit Value: {:.2f}',
        'C_D_Loss': 'C_D_Loss Value: {:.2f}',
        'I_D_Profit': 'I_D_Profit Value: {:.2f}',
        'I_D_Loss': 'I_D_Loss Value: {:.2f}'
    }

    # Add specified annotations
    for column, y_col, symbol, color, name in annotations:
        hover_text = hover_texts.get(name, '{:.2f}')
        add_annotations(column, y_col, symbol, color, name, hover_text)

    # Update layout
    fig.update_layout(
        title=chart_title,
        xaxis_title='Time',
        yaxis_title='Price',
        xaxis_rangeslider_visible=True,
        height=800,
        width=1500
    )

    return fig

# First Candlestick Chart
annotations_1 = [
    ('Entry_T', 'Low', 'triangle-up', 'green', 'Entry_T'),
    ('Defence_T', 'High', 'triangle-down', 'red', 'Defence_T'),
    ('Stop_T', 'Low', 'x', 'black', 'Stop_T'),
    ('Target_T', 'High', 'star', 'blue', 'Target_T'),
    ('T_D_Profit', 'High', 'circle', 'green', 'T_D_Profit'),
    ('T_D_Loss', 'Low', 'circle', 'red', 'T_D_Loss'),
]

fig1 = create_candlestick_chart(Final_df, 'Candlestick Chart with TRADER_DATA Annotations', annotations_1)

# Second Candlestick Chart
annotations_2 = [
    ('Entry_C', 'Low', 'triangle-up', 'green', 'Entry_C'),
    ('Defence_C', 'High', 'triangle-down', 'red', 'Defence_C'),
    ('Stop_C', 'Low', 'x', 'black', 'Stop_C'),
    ('Target_C', 'High', 'star', 'blue', 'Target_C'),
    ('C_D_Profit', 'High', 'circle', 'lightgreen', 'C_D_Profit'),
    ('C_D_Loss', 'Low', 'circle', 'lightcoral', 'C_D_Loss'),
]

fig2 = create_candlestick_chart(Final_df, 'Candlestick Chart with CALCULATED_DATA Annotations', annotations_2)

# Third Candlestick Chart
annotations_3 = [
    ('Entry_C', 'Low', 'triangle-up', 'green', 'Entry_C'),
    ('Defence_C', 'High', 'triangle-down', 'red', 'Defence_C'),
    ('Stop_C', 'Low', 'x', 'black', 'Stop_C'),
    ('Target_C', 'High', 'star', 'blue', 'Target_C'),
    ('I_D_Profit', 'High', 'circle', 'blue', 'I_D_Profit'),
    ('I_D_Loss', 'Low', 'circle', 'orange', 'I_D_Loss'),
]

fig3 = create_candlestick_chart(Final_df, 'Candlestick Chart with IDEAL_DATA Annotations', annotations_3)

# Show the plots
fig1.show()
fig2.show()
fig3.show()

# Save the figures as HTML files
fig1.write_html('/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Final_visualization_data/Plotely_Plots/candlestick_chart_TRADER_DATA_annotations.html')
fig2.write_html('/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Final_visualization_data/Plotely_Plots/candlestick_chart_CALCULATED_DATA_annotations.html')
fig3.write_html('/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Final_visualization_data/Plotely_Plots/candlestick_chart_IDEAL_DATA_annotations.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16d47d96-ec64-44b9-b7bb-7c45a2b6af6c" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16d47d96-ec64-44b9-b7bb-7c45a2b6af6c")) {                    Plotly.newPlot(                        "16d47d96-ec64-44b9-b7bb-7c45a2b6af6c",                        [{"close":[4619.25,4620.0,4620.25,4620.75,4620.5,4617.0,4617.75,4619.0,4619.0,4617.75,4620.0,4620.25,4621.25,4619.25,4619.5,4619.25,4623.5,4623.5,4623.5,4623.5,4622.0,4621.25,4621.75,4623.5,4624.0,4624.0,4623.75,4626.75,4626.75,4626.75,4626.75,4626.75,4626.75,4628.5,4628.5,4628.5,4628.0,4622.0,4619.0,4612.5,4613.75,4611.5,4612.75,4611.25,4611.75,4608.0,4614.0,4614.0,4611.25,4611.25,4616.25,4616.25,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4622.25,4622.25,4626.25,4626.25,4625.25,4621.25,4620.25,4619.0,4624.0,4622.0,4623.0,4619.25,4616.75,4615.5,4615.25,4618.0,4616.0,4618.5,4620.75,4618.5,4617.75,4618.5,4621.75,4621.75,4619.75,4623.0,4620.5,4621.0,4623.5,4620.75,4620.25,4618.75,4620.0,4618.75,4622.0,4622.0,4624.0,4627.5,4627.5,4627.5,4627.0,4623.25,4625.0,4626.25,4625.0,4626.75,4626.5,4627.25,4629.5,4629.5,4629.5,4629.5,4629.5,4633.75,4633.75,4633.75,4633.75,4633.75,4635.0,4639.0,4639.0,4640.75,4640.75,4640.75,4644.5,4644.5,4644.5,4644.5,4644.5,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4655.0,4655.0,4655.0,4655.0,4655.0,4657.25,4657.25,4657.25,4657.25,4655.75,4661.5,4661.5,4655.25,4657.25,4658.5,4659.25,4658.25,4664.5,4664.5,4664.5,4664.5,4661.75,4665.75,4665.75,4658.25,4653.0,4653.25,4653.25,4655.0,4655.0,4655.75,4661.25,4661.25,4661.25,4658.5,4661.25,4662.5,4661.75,4661.5,4654.25,4649.0,4644.0,4646.5,4644.25,4645.25,4644.25,4649.0,4647.0,4631.75,4625.5,4628.0,4629.0,4625.5,4627.0,4634.75,4634.75,4634.75,4633.0,4643.0,4643.0,4643.0,4643.0,4642.0,4634.5,4654.75,4654.75,4654.75,4654.75,4654.75,4654.75,4654.75,4657.0,4657.0,4657.0,4657.0,4660.5,4660.5,4660.5,4655.5,4661.75,4665.25,4669.5,4669.5,4669.5,4668.75,4668.5,4666.0,4663.25,4668.25,4663.0,4662.25,4667.25,4666.75,4669.0,4665.5,4668.0,4667.5,4667.5,4665.5,4666.5,4673.75,4673.75,4673.75,4673.75,4673.75,4673.75,4673.75,4672.75,4672.75,4672.25,4674.5,4673.5,4679.25,4680.0,4682.25,4690.25,4690.25,4690.25,4690.25,4690.25,4690.25,4690.25,4689.25,4684.75,4688.25,4689.5,4689.0,4691.0,4691.0,4692.75,4692.75,4692.0,4693.25,4694.25,4691.25,4695.25,4699.25,4699.25,4705.0,4705.0,4705.0,4705.0,4705.0,4705.0,4705.0,4705.75,4705.75,4709.75,4705.5,4705.0,4700.25,4701.75,4697.0,4698.75,4693.75,4701.5,4691.0,4697.25,4697.25,4697.75,4693.75,4697.25,4696.5,4696.25,4694.75,4694.75,4695.25,4695.25,4696.25,4697.25,4704.75,4704.75,4704.75,4704.75,4704.75,4704.75,4704.75,4703.0,4702.5,4702.5,4697.25,4699.0,4698.0,4697.25,4694.75,4690.25,4690.5,4688.0,4690.25,4690.25,4685.0,4685.0,4686.0,4689.25,4689.25,4691.5,4691.5,4691.5,4692.25,4689.75,4681.0,4681.0,4680.5,4673.5,4677.25,4676.5,4675.0,4679.5,4679.5,4681.75,4681.75,4679.5,4682.5,4682.0,4686.5,4686.5,4686.5,4686.5,4686.5,4687.0,4687.0,4687.0,4685.5,4684.0,4684.0,4681.0,4682.75,4683.5,4683.5,4681.5,4681.75,4681.0,4680.5,4678.25,4677.0,4677.25,4676.75,4676.25,4679.0,4679.0,4677.0,4677.25,4680.75,4680.75,4680.75,4684.75,4684.75,4684.75,4684.75,4684.75,4684.75,4686.25,4686.25,4686.25,4686.25,4686.75,4687.75,4688.5,4688.5,4690.0,4693.75,4693.75,4693.75,4693.75,4691.5,4691.5,4688.25,4690.75,4684.75,4684.5,4684.25,4685.5,4685.25,4683.0,4679.25,4676.75,4673.25,4669.5,4671.75,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4680.5,4680.5,4679.25,4678.75,4674.5,4674.0,4675.0,4667.5,4673.0,4677.25,4677.25,4671.25,4668.75,4665.5,4662.75,4666.0,4667.25,4667.25,4670.75,4670.75,4670.75,4670.5,4672.0,4677.5,46 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5a1b9c01-006e-426b-a980-f2f0c9e97b43" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a1b9c01-006e-426b-a980-f2f0c9e97b43")) {                    Plotly.newPlot(                        "5a1b9c01-006e-426b-a980-f2f0c9e97b43",                        [{"close":[4619.25,4620.0,4620.25,4620.75,4620.5,4617.0,4617.75,4619.0,4619.0,4617.75,4620.0,4620.25,4621.25,4619.25,4619.5,4619.25,4623.5,4623.5,4623.5,4623.5,4622.0,4621.25,4621.75,4623.5,4624.0,4624.0,4623.75,4626.75,4626.75,4626.75,4626.75,4626.75,4626.75,4628.5,4628.5,4628.5,4628.0,4622.0,4619.0,4612.5,4613.75,4611.5,4612.75,4611.25,4611.75,4608.0,4614.0,4614.0,4611.25,4611.25,4616.25,4616.25,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4622.25,4622.25,4626.25,4626.25,4625.25,4621.25,4620.25,4619.0,4624.0,4622.0,4623.0,4619.25,4616.75,4615.5,4615.25,4618.0,4616.0,4618.5,4620.75,4618.5,4617.75,4618.5,4621.75,4621.75,4619.75,4623.0,4620.5,4621.0,4623.5,4620.75,4620.25,4618.75,4620.0,4618.75,4622.0,4622.0,4624.0,4627.5,4627.5,4627.5,4627.0,4623.25,4625.0,4626.25,4625.0,4626.75,4626.5,4627.25,4629.5,4629.5,4629.5,4629.5,4629.5,4633.75,4633.75,4633.75,4633.75,4633.75,4635.0,4639.0,4639.0,4640.75,4640.75,4640.75,4644.5,4644.5,4644.5,4644.5,4644.5,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4655.0,4655.0,4655.0,4655.0,4655.0,4657.25,4657.25,4657.25,4657.25,4655.75,4661.5,4661.5,4655.25,4657.25,4658.5,4659.25,4658.25,4664.5,4664.5,4664.5,4664.5,4661.75,4665.75,4665.75,4658.25,4653.0,4653.25,4653.25,4655.0,4655.0,4655.75,4661.25,4661.25,4661.25,4658.5,4661.25,4662.5,4661.75,4661.5,4654.25,4649.0,4644.0,4646.5,4644.25,4645.25,4644.25,4649.0,4647.0,4631.75,4625.5,4628.0,4629.0,4625.5,4627.0,4634.75,4634.75,4634.75,4633.0,4643.0,4643.0,4643.0,4643.0,4642.0,4634.5,4654.75,4654.75,4654.75,4654.75,4654.75,4654.75,4654.75,4657.0,4657.0,4657.0,4657.0,4660.5,4660.5,4660.5,4655.5,4661.75,4665.25,4669.5,4669.5,4669.5,4668.75,4668.5,4666.0,4663.25,4668.25,4663.0,4662.25,4667.25,4666.75,4669.0,4665.5,4668.0,4667.5,4667.5,4665.5,4666.5,4673.75,4673.75,4673.75,4673.75,4673.75,4673.75,4673.75,4672.75,4672.75,4672.25,4674.5,4673.5,4679.25,4680.0,4682.25,4690.25,4690.25,4690.25,4690.25,4690.25,4690.25,4690.25,4689.25,4684.75,4688.25,4689.5,4689.0,4691.0,4691.0,4692.75,4692.75,4692.0,4693.25,4694.25,4691.25,4695.25,4699.25,4699.25,4705.0,4705.0,4705.0,4705.0,4705.0,4705.0,4705.0,4705.75,4705.75,4709.75,4705.5,4705.0,4700.25,4701.75,4697.0,4698.75,4693.75,4701.5,4691.0,4697.25,4697.25,4697.75,4693.75,4697.25,4696.5,4696.25,4694.75,4694.75,4695.25,4695.25,4696.25,4697.25,4704.75,4704.75,4704.75,4704.75,4704.75,4704.75,4704.75,4703.0,4702.5,4702.5,4697.25,4699.0,4698.0,4697.25,4694.75,4690.25,4690.5,4688.0,4690.25,4690.25,4685.0,4685.0,4686.0,4689.25,4689.25,4691.5,4691.5,4691.5,4692.25,4689.75,4681.0,4681.0,4680.5,4673.5,4677.25,4676.5,4675.0,4679.5,4679.5,4681.75,4681.75,4679.5,4682.5,4682.0,4686.5,4686.5,4686.5,4686.5,4686.5,4687.0,4687.0,4687.0,4685.5,4684.0,4684.0,4681.0,4682.75,4683.5,4683.5,4681.5,4681.75,4681.0,4680.5,4678.25,4677.0,4677.25,4676.75,4676.25,4679.0,4679.0,4677.0,4677.25,4680.75,4680.75,4680.75,4684.75,4684.75,4684.75,4684.75,4684.75,4684.75,4686.25,4686.25,4686.25,4686.25,4686.75,4687.75,4688.5,4688.5,4690.0,4693.75,4693.75,4693.75,4693.75,4691.5,4691.5,4688.25,4690.75,4684.75,4684.5,4684.25,4685.5,4685.25,4683.0,4679.25,4676.75,4673.25,4669.5,4671.75,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4680.5,4680.5,4679.25,4678.75,4674.5,4674.0,4675.0,4667.5,4673.0,4677.25,4677.25,4671.25,4668.75,4665.5,4662.75,4666.0,4667.25,4667.25,4670.75,4670.75,4670.75,4670.5,4672.0,4677.5,46 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c9686895-c48f-4db3-b22f-8b1a01e536bf" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9686895-c48f-4db3-b22f-8b1a01e536bf")) {                    Plotly.newPlot(                        "c9686895-c48f-4db3-b22f-8b1a01e536bf",                        [{"close":[4619.25,4620.0,4620.25,4620.75,4620.5,4617.0,4617.75,4619.0,4619.0,4617.75,4620.0,4620.25,4621.25,4619.25,4619.5,4619.25,4623.5,4623.5,4623.5,4623.5,4622.0,4621.25,4621.75,4623.5,4624.0,4624.0,4623.75,4626.75,4626.75,4626.75,4626.75,4626.75,4626.75,4628.5,4628.5,4628.5,4628.0,4622.0,4619.0,4612.5,4613.75,4611.5,4612.75,4611.25,4611.75,4608.0,4614.0,4614.0,4611.25,4611.25,4616.25,4616.25,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4620.75,4622.25,4622.25,4626.25,4626.25,4625.25,4621.25,4620.25,4619.0,4624.0,4622.0,4623.0,4619.25,4616.75,4615.5,4615.25,4618.0,4616.0,4618.5,4620.75,4618.5,4617.75,4618.5,4621.75,4621.75,4619.75,4623.0,4620.5,4621.0,4623.5,4620.75,4620.25,4618.75,4620.0,4618.75,4622.0,4622.0,4624.0,4627.5,4627.5,4627.5,4627.0,4623.25,4625.0,4626.25,4625.0,4626.75,4626.5,4627.25,4629.5,4629.5,4629.5,4629.5,4629.5,4633.75,4633.75,4633.75,4633.75,4633.75,4635.0,4639.0,4639.0,4640.75,4640.75,4640.75,4644.5,4644.5,4644.5,4644.5,4644.5,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4650.0,4655.0,4655.0,4655.0,4655.0,4655.0,4657.25,4657.25,4657.25,4657.25,4655.75,4661.5,4661.5,4655.25,4657.25,4658.5,4659.25,4658.25,4664.5,4664.5,4664.5,4664.5,4661.75,4665.75,4665.75,4658.25,4653.0,4653.25,4653.25,4655.0,4655.0,4655.75,4661.25,4661.25,4661.25,4658.5,4661.25,4662.5,4661.75,4661.5,4654.25,4649.0,4644.0,4646.5,4644.25,4645.25,4644.25,4649.0,4647.0,4631.75,4625.5,4628.0,4629.0,4625.5,4627.0,4634.75,4634.75,4634.75,4633.0,4643.0,4643.0,4643.0,4643.0,4642.0,4634.5,4654.75,4654.75,4654.75,4654.75,4654.75,4654.75,4654.75,4657.0,4657.0,4657.0,4657.0,4660.5,4660.5,4660.5,4655.5,4661.75,4665.25,4669.5,4669.5,4669.5,4668.75,4668.5,4666.0,4663.25,4668.25,4663.0,4662.25,4667.25,4666.75,4669.0,4665.5,4668.0,4667.5,4667.5,4665.5,4666.5,4673.75,4673.75,4673.75,4673.75,4673.75,4673.75,4673.75,4672.75,4672.75,4672.25,4674.5,4673.5,4679.25,4680.0,4682.25,4690.25,4690.25,4690.25,4690.25,4690.25,4690.25,4690.25,4689.25,4684.75,4688.25,4689.5,4689.0,4691.0,4691.0,4692.75,4692.75,4692.0,4693.25,4694.25,4691.25,4695.25,4699.25,4699.25,4705.0,4705.0,4705.0,4705.0,4705.0,4705.0,4705.0,4705.75,4705.75,4709.75,4705.5,4705.0,4700.25,4701.75,4697.0,4698.75,4693.75,4701.5,4691.0,4697.25,4697.25,4697.75,4693.75,4697.25,4696.5,4696.25,4694.75,4694.75,4695.25,4695.25,4696.25,4697.25,4704.75,4704.75,4704.75,4704.75,4704.75,4704.75,4704.75,4703.0,4702.5,4702.5,4697.25,4699.0,4698.0,4697.25,4694.75,4690.25,4690.5,4688.0,4690.25,4690.25,4685.0,4685.0,4686.0,4689.25,4689.25,4691.5,4691.5,4691.5,4692.25,4689.75,4681.0,4681.0,4680.5,4673.5,4677.25,4676.5,4675.0,4679.5,4679.5,4681.75,4681.75,4679.5,4682.5,4682.0,4686.5,4686.5,4686.5,4686.5,4686.5,4687.0,4687.0,4687.0,4685.5,4684.0,4684.0,4681.0,4682.75,4683.5,4683.5,4681.5,4681.75,4681.0,4680.5,4678.25,4677.0,4677.25,4676.75,4676.25,4679.0,4679.0,4677.0,4677.25,4680.75,4680.75,4680.75,4684.75,4684.75,4684.75,4684.75,4684.75,4684.75,4686.25,4686.25,4686.25,4686.25,4686.75,4687.75,4688.5,4688.5,4690.0,4693.75,4693.75,4693.75,4693.75,4691.5,4691.5,4688.25,4690.75,4684.75,4684.5,4684.25,4685.5,4685.25,4683.0,4679.25,4676.75,4673.25,4669.5,4671.75,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4677.5,4680.5,4680.5,4679.25,4678.75,4674.5,4674.0,4675.0,4667.5,4673.0,4677.25,4677.25,4671.25,4668.75,4665.5,4662.75,4666.0,4667.25,4667.25,4670.75,4670.75,4670.75,4670.5,4672.0,4677.5,46 ...
