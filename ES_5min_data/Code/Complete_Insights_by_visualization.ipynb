# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from plotly.subplots import make_subplots
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Final_df = pd.read_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Machine_Learning_Model/Final_DF.csv")

# %%
Final_df.tail()
# Out:
#       Unnamed: 0           Time Stamp     Open     High      Low    Close  \
# 1974        1974  2021-10-07 23:35:00  4739.25  4741.25  4739.25  4740.25
# 1975        1975  2021-10-07 23:40:00  4740.25  4741.00  4740.00  4740.25
# 1976        1976  2021-10-07 23:45:00  4740.50  4740.75  4739.75  4740.50
# 1977        1977  2021-10-07 23:50:00  4740.25  4740.75  4738.50  4739.00
# 1978        1978  2021-10-07 23:55:00  4739.00  4739.75  4738.25  4738.25
#
#       SellersLevel4  SellersLevel3  SellersLevel2  SellersLevel1  ...  \
# 1974        4742.75        4742.75        4741.75        4740.75  ...
# 1975        4742.75        4742.50        4741.75        4740.75  ...
# 1976        4742.75        4742.75        4742.50        4741.75  ...
# 1977        4742.50        4741.75        4741.25        4740.75  ...
# 1978        4741.25        4741.00        4740.75        4740.50  ...
#
#       Profit_C  Loss_C  Profit_Ideal  Loss_Ideal  T_D_Profit  T_D_Loss  \
# ...

# %%
Final_df.drop(columns=["Unnamed: 0"],axis=1,inplace=True)
Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])

# Define the start and end times for filtering
start_time = '2021-10-01 00:00:00'
end_time = '2021-10-07 23:55:00'

# Filter the DataFrame for the specific time range
Final_df = Final_df[(Final_df['Time Stamp'] > start_time) & (Final_df['Time Stamp'] <= end_time)]

# %%
Final_df.head()
# Out:
#            Time Stamp     Open     High      Low    Close  SellersLevel4  \
# 0 2021-10-01 00:05:00  4619.00  4621.00  4618.75  4619.25        4622.50
# 1 2021-10-01 00:10:00  4619.00  4620.25  4618.50  4620.00        4622.50
# 2 2021-10-01 00:15:00  4619.75  4620.25  4618.50  4620.25        4623.00
# 3 2021-10-01 00:20:00  4620.00  4621.00  4619.75  4620.75        4623.00
# 4 2021-10-01 00:25:00  4620.75  4620.75  4619.25  4620.50        4623.25
#
#    SellersLevel3  SellersLevel2  SellersLevel1  SellersLevel0  ...  Profit_C  \
# 0        4621.25        4620.25        4620.00        4619.25  ...      0.00
# 1        4621.25        4620.25        4620.00        4619.25  ...     71.25
# 2        4622.50        4621.25        4620.25        4620.00  ...     71.25
# 3        4622.50        4621.25        4621.00        4620.25  ...    543.50
# 4        4623.00        4622.50        4621.25        4621.00  ...      0.00
#
# ...

# %%
Final_df.shape
# Out:
# (1979, 43)

# %%
import pandas as pd
import plotly.graph_objects as go

# Ensure that the 'Time Stamp' column is in datetime format
Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])

# Create a candlestick chart
fig = go.Figure(data=[go.Candlestick(x=Final_df['Time Stamp'],
                                     open=Final_df['Open'],
                                     high=Final_df['High'],
                                     low=Final_df['Low'],
                                     close=Final_df['Close'])])

# Function to add annotations
def add_annotations(df, column, y_col, symbol, color, name):
    signals = df[df[column] != 0]
    fig.add_trace(go.Scatter(x=signals['Time Stamp'],
                             y=signals[y_col],
                             mode='markers',
                             marker=dict(symbol=symbol, size=10, color=color),
                             name=name))

# Add annotations for Entry_T
add_annotations(Final_df, 'Entry_T', 'Low', 'triangle-up', 'green', 'Entry_T')

# Add annotations for Defence_T
add_annotations(Final_df, 'Defence_T', 'High', 'triangle-down', 'red', 'Defence_T')

# Add annotations for Stop_T
add_annotations(Final_df, 'Stop_T', 'Low', 'x', 'black', 'Stop_T')

# Add annotations for Target_T
add_annotations(Final_df, 'Target_T', 'High', 'star', 'blue', 'Target_T')

# Add annotations for Defence_C
add_annotations(Final_df, 'Defence_C', 'High', 'triangle-down', 'purple', 'Defence_C')

# Add annotations for Stop_C
add_annotations(Final_df, 'Stop_C', 'Low', 'x', 'orange', 'Stop_C')

# Add annotations for Target_C
add_annotations(Final_df, 'Target_C', 'High', 'star', 'cyan', 'Target_C')

# Add annotations for Target_Ideal
add_annotations(Final_df, 'Target_Ideal', 'High', 'star', 'magenta', 'Target_Ideal')

# Add annotations for defence_target_T
add_annotations(Final_df, 'defence_target_T', 'Low', 'triangle-up', 'pink', 'defence_target_T')

# Add annotations for defence_target_C
add_annotations(Final_df, 'defence_target_C', 'Low', 'triangle-up', 'yellow', 'defence_target_C')

# Add annotations for Profit_T
add_annotations(Final_df, 'Profit_T', 'High', 'diamond', 'green', 'Profit_T')

# Add annotations for Loss_T
add_annotations(Final_df, 'Loss_T', 'Low', 'diamond', 'red', 'Loss_T')

# Add annotations for Profit_C
add_annotations(Final_df, 'Profit_C', 'High', 'diamond', 'lightgreen', 'Profit_C')

# Add annotations for Loss_C
add_annotations(Final_df, 'Loss_C', 'Low', 'diamond', 'lightcoral', 'Loss_C')

# Add annotations for T_D_Profit
add_annotations(Final_df, 'T_D_Profit', 'High', 'circle', 'green', 'T_D_Profit')

# Add annotations for T_D_Loss
add_annotations(Final_df, 'T_D_Loss', 'Low', 'circle', 'red', 'T_D_Loss')

# Add annotations for C_D_Profit
add_annotations(Final_df, 'C_D_Profit', 'High', 'circle', 'lightgreen', 'C_D_Profit')

# Add annotations for C_D_Loss
add_annotations(Final_df, 'C_D_Loss', 'Low', 'circle', 'lightcoral', 'C_D_Loss')

# Add annotations for I_D_Profit
add_annotations(Final_df, 'I_D_Profit', 'High', 'circle', 'blue', 'I_D_Profit')

# Add annotations for I_D_Loss
add_annotations(Final_df, 'I_D_Loss', 'Low', 'circle', 'orange', 'I_D_Loss')

# Update layout with range slider
fig.update_layout(title='Candlestick Chart with Annotations',
                  xaxis_title='Time',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=True)

fig.update_layout(height=1000)
fig.update_layout(width=1800)
# Show plot
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Ensure that the 'Time Stamp' column is in datetime format
Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])

# Create a subplot with two rows
fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
                    subplot_titles=('Candlestick Chart', 'Data Comparison'))

# First chart: Candlestick chart with only open, high, low, close
fig.add_trace(go.Candlestick(x=Final_df['Time Stamp'],
                             open=Final_df['Open'],
                             high=Final_df['High'],
                             low=Final_df['Low'],
                             close=Final_df['Close'],
                             name='Candlestick'),
              row=1, col=1)

# Second chart: Comparison of trader and calculated data
comparison_columns = [
    ('Entry_T', 'green', 'Trader Entry'),
    ('Entry_C', 'orange', 'Calculated Entry'),
    ('Defence_T', 'red', 'Trader Defence'),
    ('Defence_C', 'purple', 'Calculated Defence'),
    ('Stop_T', 'black', 'Trader Stop'),
    ('Stop_C', 'brown', 'Calculated Stop'),
    ('Target_T', 'blue', 'Trader Target'),
    ('Target_C', 'cyan', 'Calculated Target'),
    ('Target_Ideal', 'magenta', 'Ideal Target'),
    ('defence_target_T', 'pink', 'Defence Trader Target'),
    ('defence_target_C', 'yellow', 'Defence Calculated Target'),
    ('Profit_T', 'lightgreen', 'Trader Profit'),
    ('Loss_T', 'lightcoral', 'Trader Loss'),
    ('Profit_C', 'lightblue', 'Calculated Profit'),
    ('Loss_C', 'lightpink', 'Calculated Loss'),
    ('Profit_Ideal', 'green', 'Ideal Profit'),
    ('Loss_Ideal', 'red', 'Ideal Loss'),
    ('T_D_Profit', 'blue', 'Trader Defence Profit'),
    ('T_D_Loss', 'orange', 'Trader Defence Loss'),
    ('C_D_Profit', 'purple', 'Calculated Defence Profit'),
    ('C_D_Loss', 'brown', 'Calculated Defence Loss'),
    ('I_D_Profit', 'cyan', 'Ideal Defence Profit'),
    ('I_D_Loss', 'magenta', 'Ideal Defence Loss')
]

# Loop through the comparison columns and add bar traces to the second chart
for column, color, name in comparison_columns:
    fig.add_trace(go.Bar(x=Final_df['Time Stamp'],
                         y=Final_df[column],
                         name=name,
                         marker_color=color),
                  row=2, col=1)

# Update layout with range slider and titles
fig.update_layout(title='Candlestick Chart and Data Comparison',
                  xaxis_title='Time',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=True,
                  height=1000)

# Show plot
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Final_df.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlTime', 'BuyersInControlPrice',
#        'SellersInControlTime', 'SellersInControlPrice', 'Entry_T', 'Entry_C',
#        'Defence_T', 'Defence_C', 'Stop_T', 'Stop_C', 'Target_T', 'Target_C',
#        'Target_Ideal', 'defence_target_T', 'defence_target_C',
#        'defence_target_Ideal', 'Profit_T', 'Loss_T', 'Profit_C', 'Loss_C',
#        'Profit_Ideal', 'Loss_Ideal', 'T_D_Profit', 'T_D_Loss', 'C_D_Profit',
#        'C_D_Loss', 'I_D_Profit', 'I_D_Loss'],
#       dtype='object')

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create a subplot with three rows
fig = make_subplots(
    rows=3, cols=1,
    subplot_titles=('BuyersInControlPrice', 'SellersInControlPrice', 'Profit/Loss'),
    shared_xaxes=True
)

# Add the candlestick chart to the first and second subplots
fig.add_trace(go.Candlestick(
    x=Final_df.index,
    open=Final_df['Open'],
    high=Final_df['High'],
    low=Final_df['Low'],
    close=Final_df['Close'],
    name='Candlestick'
), row=1, col=1)

fig.add_trace(go.Candlestick(
    x=Final_df.index,
    open=Final_df['Open'],
    high=Final_df['High'],
    low=Final_df['Low'],
    close=Final_df['Close'],
    name='Candlestick'
), row=2, col=1)

# Add horizontal lines and annotations for BuyersInControlPrice
for index, row in Final_df.iterrows():
    if row['BuyersInControlPrice'] != 0:
        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['BuyersInControlPrice'], row['BuyersInControlPrice']],
            mode='lines+text',
            line=dict(color='green', width=2),
            text=[f'Entry_T: {row["BuyersInControlPrice"]}', f'Entry_T: {row["BuyersInControlPrice"]}'],
            textposition='bottom left',
            hovertext=f'Entry_T: {row["BuyersInControlPrice"]}',
            hoverinfo='text',
            name='Entry_T',
            showlegend=False
        ), row=1, col=1)

        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['Defence_T'], row['Defence_T']],
            mode='lines+text',
            line=dict(color='blue', width=2),
            text=[f'Defence_T: {row["Defence_T"]}', f'Defence_T: {row["Defence_T"]}'],
            textposition='bottom left',
            hovertext=f'Defence_T: {row["Defence_T"]}',
            hoverinfo='text',
            name='Defence_T',
            showlegend=False
        ), row=1, col=1)

        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['Stop_T'], row['Stop_T']],
            mode='lines+text',
            line=dict(color='purple', width=2),
            text=[f'Stop_T: {row["Stop_T"]}', f'Stop_T: {row["Stop_T"]}'],
            textposition='bottom left',
            hovertext=f'Stop_T: {row["Stop_T"]}',
            hoverinfo='text',
            name='Stop_T',
            showlegend=False
        ), row=1, col=1)

        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['Target_T'], row['Target_T']],
            mode='lines+text',
            line=dict(color='red', width=2),
            text=[f'Target_T: {row["Target_T"]}', f'Target_T: {row["Target_T"]}'],
            textposition='bottom left',
            hovertext=f'Target_T: {row["Target_T"]}',
            hoverinfo='text',
            name='Target_T',
            showlegend=False
        ), row=1, col=1)

# Add horizontal lines and annotations for SellersInControlPrice
for index, row in Final_df.iterrows():
    if row['SellersInControlPrice'] != 0:
        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['SellersInControlPrice'], row['SellersInControlPrice']],
            mode='lines+text',
            line=dict(color='orange', width=2),
            text=[f'Entry_T: {row["SellersInControlPrice"]}', f'Entry_T: {row["SellersInControlPrice"]}'],
            textposition='bottom left',
            hovertext=f'Entry_T: {row["SellersInControlPrice"]}',
            hoverinfo='text',
            name='Entry_T',
            showlegend=False
        ), row=2, col=1)

        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['Defence_T'], row['Defence_T']],
            mode='lines+text',
            line=dict(color='cyan', width=2),
            text=[f'Defence_T: {row["Defence_T"]}', f'Defence_T: {row["Defence_T"]}'],
            textposition='bottom left',
            hovertext=f'Defence_T: {row["Defence_T"]}',
            hoverinfo='text',
            name='Defence_T',
            showlegend=False
        ), row=2, col=1)

        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['Stop_T'], row['Stop_T']],
            mode='lines+text',
            line=dict(color='magenta', width=2),
            text=[f'Stop_T: {row["Stop_T"]}', f'Stop_T: {row["Stop_T"]}'],
            textposition='bottom left',
            hovertext=f'Stop_T: {row["Stop_T"]}',
            hoverinfo='text',
            name='Stop_T',
            showlegend=False
        ), row=2, col=1)

        fig.add_trace(go.Scatter(
            x=[Final_df.index.min(), Final_df.index.max()],
            y=[row['Target_T'], row['Target_T']],
            mode='lines+text',
            line=dict(color='red', width=2),
            text=[f'Target_T: {row["Target_T"]}', f'Target_T: {row["Target_T"]}'],
            textposition='bottom left',
            hovertext=f'Target_T: {row["Target_T"]}',
            hoverinfo='text',
            name='Target_T',
            showlegend=False
        ), row=2, col=1)

# Add the candlestick chart to the third subplot for Profit/Loss with hovertext
fig.add_trace(go.Candlestick(
    x=Final_df.index,
    open=Final_df['Open'],
    high=Final_df['High'],
    low=Final_df['Low'],
    close=Final_df['Close'],
    name='Candlestick',
    hovertext=[
        f'Profit: {row["Profit_T"]}, Loss: {row["Loss_T"]}'
        for index, row in Final_df.iterrows()
    ],
    hoverinfo='text'
), row=3, col=1)

# Add markers for Profit and Loss in the third subplot
for index, row in Final_df.iterrows():
    if row['Profit_T'] > 0:
        marker_color = 'green'
        marker_text = f'Profit: {row["Profit_T"]}'
    else:
        marker_color = 'red'
        marker_text = f'Loss: {row["Loss_T"]}'

    fig.add_trace(go.Scatter(
        x=[row['Time Stamp']],
        y=[(row['High'] + row['Low']) / 2],
        mode='markers',
        marker=dict(color=marker_color, size=10),
        hovertext=marker_text,
        hoverinfo='text',
        name='Profit/Loss',
        showlegend=False
    ), row=3, col=1)

# Update layout
fig.update_layout(
    title='Candlestick Chart with BuyersInControlPrice, SellersInControlPrice, and Profit/Loss',
    xaxis_title='Time',
    yaxis_title='Price',
    xaxis_rangeslider_visible=False,
    xaxis_tickformat='%Y-%m-%d %H:%M:%S',  # Format x-axis to show date and time
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    height=800  # Increase height to accommodate three subplots
)

# Show the plot (for interactive use)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Sample DataFrame (replace with your actual Final_df)
# Ensure your 'Time Stamp' column is in datetime format
Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])
Final_df.set_index('Time Stamp', inplace=True)
# Initialize the Dash app
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Candlestick Chart with Date Filter"),

    dcc.DatePickerSingle(
        id='date-picker',
        date=Final_df.index[0].date(),  # Set default date to the first date in the DataFrame
        display_format='YYYY-MM-DD'
    ),

    dcc.Graph(id='candlestick-graph'),
])

@app.callback(
    Output('candlestick-graph', 'figure'),
    Input('date-picker', 'date')
)
def update_graph(selected_date):
    # Filter the DataFrame based on the selected date
    filtered_df = Final_df[Final_df.index.date == pd.to_datetime(selected_date).date()]

    # Create a subplot with three rows
    fig = make_subplots(
        rows=3, cols=1,
        subplot_titles=('BuyersInControlPrice', 'SellersInControlPrice', 'Profit/Loss'),
        shared_xaxes=True
    )

    # Add the candlestick chart to the first subplot
    fig.add_trace(go.Candlestick(
        x=filtered_df.index,
        open=filtered_df['Open'],
        high=filtered_df['High'],
        low=filtered_df['Low'],
        close=filtered_df['Close'],
        name='Candlestick'
    ), row=1, col=1)

    # Add horizontal lines and annotations for BuyersInControlPrice
    for index, row in filtered_df.iterrows():
        if row['BuyersInControlPrice'] != 0:
            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['BuyersInControlPrice'], row['BuyersInControlPrice']],
                mode='lines+text',
                line=dict(color='green', width=2),
                text=[f'Entry_T: {row["BuyersInControlPrice"]}', f'Entry_T: {row["BuyersInControlPrice"]}'],
                textposition='bottom left',
                hovertext=f'Entry_T: {row["BuyersInControlPrice"]}',
                hoverinfo='text',
                name='Entry_T',
                showlegend=False
            ), row=1, col=1)

            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['Defence_T'], row['Defence_T']],
                mode='lines+text',
                line=dict(color='blue', width=2),
                text=[f'Defence_T: {row["Defence_T"]}', f'Defence_T: {row["Defence_T"]}'],
                textposition='bottom left',
                hovertext=f'Defence_T: {row["Defence_T"]}',
                hoverinfo='text',
                name='Defence_T',
                showlegend=False
            ), row=1, col=1)

            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['Stop_T'], row['Stop_T']],
                mode='lines+text',
                line=dict(color='purple', width=2),
                text=[f'Stop_T: {row["Stop_T"]}', f'Stop_T: {row["Stop_T"]}'],
                textposition='bottom left',
                hovertext=f'Stop_T: {row["Stop_T"]}',
                hoverinfo='text',
                name='Stop_T',
                showlegend=False
            ), row=1, col=1)

            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['Target_T'], row['Target_T']],
                mode='lines+text',
                line=dict(color='red', width=2),
                text=[f'Target_T: {row["Target_T"]}', f'Target_T: {row["Target_T"]}'],
                textposition='bottom left',
                hovertext=f'Target_T: {row["Target_T"]}',
                hoverinfo='text',
                name='Target_T',
                showlegend=False
            ), row=1, col=1)

    # Add the candlestick chart to the second subplot for SellersInControlPrice
    fig.add_trace(go.Candlestick(
        x=filtered_df.index,
        open=filtered_df['Open'],
        high=filtered_df['High'],
        low=filtered_df['Low'],
        close=filtered_df['Close'],
        name='Candlestick'
    ), row=2, col=1)

    # Add horizontal lines and annotations for SellersInControlPrice
    for index, row in filtered_df.iterrows():
        if row['SellersInControlPrice'] != 0:
            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['SellersInControlPrice'], row['SellersInControlPrice']],
                mode='lines+text',
                line=dict(color='orange', width=2),
                text=[f'Entry_T: {row["SellersInControlPrice"]}', f'Entry_T: {row["SellersInControlPrice"]}'],
                textposition='bottom left',
                hovertext=f'Entry_T: {row["SellersInControlPrice"]}',
                hoverinfo='text',
                name='Entry_T',
                showlegend=False
            ), row=2, col=1)

            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['Defence_T'], row['Defence_T']],
                mode='lines+text',
                line=dict(color='cyan', width=2),
                text=[f'Defence_T: {row["Defence_T"]}', f'Defence_T: {row["Defence_T"]}'],
                textposition='bottom left',
                hovertext=f'Defence_T: {row["Defence_T"]}',
                hoverinfo='text',
                name='Defence_T',
                showlegend=False
            ), row=2, col=1)

            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['Stop_T'], row['Stop_T']],
                mode='lines+text',
                line=dict(color='magenta', width=2),
                text=[f'Stop_T: {row["Stop_T"]}', f'Stop_T: {row["Stop_T"]}'],
                textposition='bottom left',
                hovertext=f'Stop_T: {row["Stop_T"]}',
                hoverinfo='text',
                name='Stop_T',
                showlegend=False
            ), row=2, col=1)

            fig.add_trace(go.Scatter(
                x=[filtered_df.index.min(), filtered_df.index.max()],
                y=[row['Target_T'], row['Target_T']],
                mode='lines+text',
                line=dict(color='red', width=2),
                text=[f'Target_T: {row["Target_T"]}', f'Target_T: {row["Target_T"]}'],
                textposition='bottom left',
                hovertext=f'Target_T: {row["Target_T"]}',
                hoverinfo='text',
                name='Target_T',
                showlegend=False
            ), row=2, col=1)

    # Add the candlestick chart to the third subplot for Profit/Loss with hovertext
    fig.add_trace(go.Candlestick(
        x=filtered_df.index,
        open=filtered_df['Open'],
        high=filtered_df['High'],
        low=filtered_df['Low'],
        close=filtered_df['Close'],
        name='Candlestick',
        hovertext=[
            f'Profit: {row["Profit_T"]}, Loss: {row["Loss_T"]}'
            for index, row in filtered_df.iterrows()
        ],
        hoverinfo='text'
    ), row=3, col=1)

    # Add markers for Profit and Loss in the third subplot
    for index, row in filtered_df.iterrows():
        if row['Profit_T'] > 0:
            marker_color = 'green'
            marker_text = f'Profit: {row["Profit_T"]}'
        else:
            marker_color = 'red'
            marker_text = f'Loss: {row["Loss_T"]}'

        fig.add_trace(go.Scatter(
            x=[index],
            y=[(row['High'] + row['Low']) / 2],
            mode='markers',
            marker=dict(color=marker_color, size=10),
            hovertext=marker_text,
            hoverinfo='text',
            name='Profit/Loss',
            showlegend=False
        ), row=3, col=1)

    # Update layout
    fig.update_layout(
        title='Candlestick Chart with BuyersInControlPrice, SellersInControlPrice, and Profit/Loss',
        xaxis_title='Time',
        yaxis_title='Price',
        xaxis_rangeslider_visible=False,
        xaxis_tickformat='%Y-%m-%d %H:%M:%S',
        xaxis_tickangle=-45,
        height=800
    )

    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Sample DataFrame (replace with your actual Final_df)
#Final_df['Time Stamp'] = pd.to_datetime(Final_df['Time Stamp'])
#Final_df.set_index('Time Stamp', inplace=True)

# Initialize the Dash app
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Candlestick Chart with Date Filter"),

    dcc.DatePickerSingle(
        id='date-picker',
        date=Final_df.index[0].date(),  # Set default date to the first date in the DataFrame
        display_format='YYYY-MM-DD'
    ),

    dcc.Graph(id='candlestick-graph'),
])

@app.callback(
    Output('candlestick-graph', 'figure'),
    Input('date-picker', 'date')
)
def update_graph(selected_date):
    # Filter the DataFrame based on the selected date
    filtered_df = Final_df[Final_df.index.date == pd.to_datetime(selected_date).date()]

    # Select two random entries for BuyersInControlPrice
    buyers_entries = filtered_df[filtered_df['BuyersInControlPrice'] != 0].sample(n=2, random_state=1)

    # Select two random entries for SellersInControlPrice
    sellers_entries = filtered_df[filtered_df['SellersInControlPrice'] != 0].sample(n=1, random_state=1)

    # Create a subplot with three rows
    fig = make_subplots(
        rows=3, cols=1,
        subplot_titles=('BuyersInControlPrice', 'SellersInControlPrice', 'Profit/Loss'),
        shared_xaxes=True
    )

    # Add the candlestick chart to the first subplot
    fig.add_trace(go.Candlestick(
        x=filtered_df.index,
        open=filtered_df['Open'],
        high=filtered_df['High'],
        low=filtered_df['Low'],
        close=filtered_df['Close'],
        name='Candlestick'
    ), row=1, col=1)

    # Add horizontal lines for selected BuyersInControlPrice entries
    for index, row in buyers_entries.iterrows():
        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['BuyersInControlPrice'], row['BuyersInControlPrice']],
            mode='lines',
            line=dict(color='green', width=1),
            hovertext=f'Entry_T: {row["BuyersInControlPrice"]}',
            hoverinfo='text',
            name='BuyersInControlPrice',
            showlegend=True
        ), row=1, col=1)

        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['Defence_T'], row['Defence_T']],
            mode='lines',
            line=dict(color='blue', width=1),
            hovertext=f'Defence_T: {row["Defence_T"]}',
            hoverinfo='text',
            name='Defence_T',
            showlegend=True
        ), row=1, col=1)

        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['Stop_T'], row['Stop_T']],
            mode='lines',
            line=dict(color='purple', width=1),
            hovertext=f'Stop_T: {row["Stop_T"]}',
            hoverinfo='text',
            name='Stop_T',
            showlegend=True
        ), row=1, col=1)

        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['Target_T'], row['Target_T']],
            mode='lines',
            line=dict(color='red', width=1),
            hovertext=f'Target_T: {row["Target_T"]}',
            hoverinfo='text',
            name='Target_T',
            showlegend=True
        ), row=1, col=1)

    # Add the candlestick chart to the second subplot for SellersInControlPrice
    fig.add_trace(go.Candlestick(
        x=filtered_df.index,
        open=filtered_df['Open'],
        high=filtered_df['High'],
        low=filtered_df['Low'],
        close=filtered_df['Close'],
        name='Candlestick'
    ), row=2, col=1)

    # Add horizontal lines for selected SellersInControlPrice entries
    for index, row in sellers_entries.iterrows():
        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['SellersInControlPrice'], row['SellersInControlPrice']],
            mode='lines',
            line=dict(color='orange', width=1),
            hovertext=f'Entry_T: {row["SellersInControlPrice"]}',
            hoverinfo='text',
            name='SellersInControlPrice',
            showlegend=True
        ), row=2, col=1)

        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['Defence_T'], row['Defence_T']],
            mode='lines',
            line=dict(color='cyan', width=1),
            hovertext=f'Defence_T: {row["Defence_T"]}',
            hoverinfo='text',
            name='Defence_T',
            showlegend=True
        ), row=2, col=1)

        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['Stop_T'], row['Stop_T']],
            mode='lines',
            line=dict(color='magenta', width=1),
            hovertext=f'Stop_T: {row["Stop_T"]}',
            hoverinfo='text',
            name='Stop_T',
            showlegend=True
        ), row=2, col=1)

        fig.add_trace(go.Scatter(
            x=[filtered_df.index.min(), filtered_df.index.max()],
            y=[row['Target_T'], row['Target_T']],
            mode='lines',
            line=dict(color='red', width=1),
            hovertext=f'Target_T: {row["Target_T"]}',
            hoverinfo='text',
            name='Target_T',
            showlegend=True
        ), row=2, col=1)

    # Add the candlestick chart to the third subplot for Profit/Loss with hovertext
    fig.add_trace(go.Candlestick(
        x=filtered_df.index,
        open=filtered_df['Open'],
        high=filtered_df['High'],
        low=filtered_df['Low'],
        close=filtered_df['Close'],
        name='Candlestick',
        hovertext=[
            f'Profit: {row["Profit_T"]}, Loss: {row["Loss_T"]}'
            for index, row in filtered_df.iterrows()
        ],
        hoverinfo='text'
    ), row=3, col=1)

    # Add markers for Profit and Loss in the third subplot
    for index, row in filtered_df.iterrows():
        if row['Profit_T'] > 0:
            marker_color = 'green'
            marker_text = f'Profit: {row["Profit_T"]}'
        else:
            marker_color = 'red'
            marker_text = f'Loss: {row["Loss_T"]}'

        fig.add_trace(go.Scatter(
            x=[index],
            y=[(row['High'] + row['Low']) / 2],
            mode='markers',
            marker=dict(color=marker_color, size=10),
            hovertext=marker_text,
            hoverinfo='text',
            name='Profit/Loss',
            showlegend=False
        ), row=3, col=1)

    # Update layout
    fig.update_layout(
        title='Candlestick Chart with BuyersInControlPrice, SellersInControlPrice, and Profit/Loss',
        xaxis_title='Time',
        yaxis_title='Price',
        xaxis_rangeslider_visible=False,
        xaxis_tickformat='%Y-%m-%d %H:%M:%S',
        xaxis_tickangle=-45,
        height=800
    )

    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
